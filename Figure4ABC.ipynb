# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import scipy.stats as stats
from scipy.stats import ttest_ind
from scipy.stats import f_oneway
from scipy.stats import kruskal
from scipy.stats import linregress
data = pd.read_excel(r"C:\Users\然\Desktop\sea-ad_cohort_donor_metadata_072524.xlsx")

# %%
dementia_age = data.iloc[:, 19]
neuron_ratios = data.iloc[:, 69]
mmse_scores = pd.to_numeric(dementia_age, errors='coerce')
neuron_ratios = pd.to_numeric(neuron_ratios, errors='coerce')
data = pd.DataFrame({'dementia_age': dementia_age, 'Neuron': neuron_ratios}).dropna()
print(data)
# Out:
#     dementia_age     Neuron
# 3           81.0  25.346615
# 6           92.0  27.009181
# 10          84.0  28.219561
# 11          84.0  31.946669
# 12          67.0  14.926142
# 13          74.0  24.456522
# 20          94.0  15.557354
# 21          89.0  28.016282
# 23          86.0  21.688034
# 25          60.0  18.480734
# 29          94.0  21.145077
# 30          86.0  17.722829
# 36          65.0  16.420155
# 37          91.0  14.875570
# 38          78.0   0.033483
# 39          65.0  19.469806
# 42          91.0  19.723227
# 44          84.0  16.743173
# 45          83.0  14.511383
# 49          90.0  27.025937
# 50          84.0  23.349306
# 53          93.0  23.366100
# 54          92.0  19.222979
# 55          89.0  31.264204
# 57          81.0   6.387531
# 58          97.0  21.933795
# 65          83.0  17.606345
# 70          86.0   8.945880
# 79          94.0  24.124514
# 80          88.0  24.633671
# 81          78.0  19.269711
# 82          94.0  27.050093

# %%
dementia_age = data['dementia_age']
neuron_ratios = data['Neuron']
slope, intercept, r_value, p_value, std_err = linregress(dementia_age, neuron_ratios)
fit_line = slope * dementia_age + intercept

plt.figure(figsize=(8, 6))
plt.scatter(dementia_age, neuron_ratios, color='blue', label='Data Points')
plt.plot(dementia_age, fit_line, color='red', label=f'Fit Line: y={slope:.2f}x+{intercept:.2f}')
plt.title('dementia_age vs IL2/3 Ratios', fontsize=14)
plt.xlabel('dementia_age', fontsize=12)
plt.ylabel('Neuron Ratios', fontsize=12)
plt.legend(fontsize=12)
plt.grid(alpha=0.3)
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"R-squared: {r_value**2:.4f}")
print(f"P-value: {p_value:.4e}")
plt.show()
# Out:
# Slope: 0.2133
# Intercept: 2.3461
# R-squared: 0.0834
# P-value: 1.0892e-01
